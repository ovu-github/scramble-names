# %%
import os
import pandas as pd
import random
folder = '/media/m/1083-4BEC/'

# %%
mp3s = []

[mp3s.append(file) for file in os.listdir(folder) if '.mp3' in file]


mp3s
# Out:
# ['Cartoon - On & On (Lyrics) feat. Daniel Levi.mp3',
#  "Herve Vilard - Capri C'est Fini.mp3",
#  'Sukiyaki (Remastered)-T_WuE_AV6kg.mp3',
#  'ABBA I Have A Dream.mp3',
#  'Living Doll (Digitally Remastered).mp3',
#  'John Lennon - Imagine (Lyrics)🎶.mp3',
#  "The Blue Diamonds-Cathy's Clown-1960.mp3",
#  'Beautiful Boy (Darling Boy).mp3',
#  'China In Your Heart.mp3',
#  "Ferre Grignard Ring Ring I've Got To Sing.mp3",
#  'Oh! Carol  -  The Blue Diamonds.mp3',
#  'The Blue Diamonds  - Till I Kissed You.mp3',
#  'rob de nijs - banger hart.mp3',
#  'The Blue Diamonds - Little Ship [_Audio_].mp3',
#  "T'Pau   China In Your Hand   Lyrics.mp3",
#  'The Bangles - Manic Monday (HD LYRICS).mp3',
#  'The Ronettes - Be My Baby (Official Audio).mp3',
#  "C.Jérome - C'est moi.mp3",
#  'Sloop John B (Remastered).mp3',
#  "The Beach Boys - Surfin' USA.mp3",
#  'Rob de Nijs - Ritme van de regen.mp3',
#  'Stef Bos - Papa lyrics.mp3',
#  'The Shadows - Kon Tiki.mp3',
# ...

# %%
random.shuffle(mp3s)
mp3s
# Out:
# ['Sukiyaki (Remastered)-T_WuE_AV6kg.mp3',
#  'rob de nijs - banger hart.mp3',
#  'Oh! Carol  -  The Blue Diamonds.mp3',
#  'Cartoon - On & On (Lyrics) feat. Daniel Levi.mp3',
#  'Stef Bos - Papa lyrics.mp3',
#  "C.Jérome - C'est moi.mp3",
#  'John Lennon - Imagine (Lyrics)🎶.mp3',
#  'Benny Neyman - Ga niet weg van mij  _ 1987 .mp3',
#  'The Ronettes - Be My Baby (Official Audio).mp3',
#  "The Beach Boys - Surfin' USA.mp3",
#  'ABBA Take a Chance On Me.mp3',
#  'China In Your Heart.mp3',
#  'Spanish Harlem.mp3',
#  'Each Time You Break My Heart.mp3',
#  'The Blue Diamonds  - Till I Kissed You.mp3',
#  'Peter Maffay - Du 1970.mp3',
#  'Amy Macdonald - Fire (Official Audio).mp3',
#  'The Blue Diamonds - Little Ship [_Audio_].mp3',
#  "The Blue Diamonds-Cathy's Clown-1960.mp3",
#  'Move It.mp3',
#  'Beautiful Boy (Darling Boy).mp3',
#  'Julio Iglesias Manuela.mp3',
#  'The Bangles - Manic Monday (HD LYRICS).mp3',
#  'Boudewijn de groot testament.mp3',
# ...

# %%
nl = '\n'

for count, file in enumerate(mp3s):
    print(f'will rename: {folder + file} to {nl} {folder + str(count) + file}')
    os.rename(folder + file,
              folder + str(count) + file)
# Out:
# will rename /media/m/1083-4BEC/Sukiyaki (Remastered)-T_WuE_AV6kg.mp3 to /media/m/1083-4BEC/0Sukiyaki (Remastered)-T_WuE_AV6kg.mp3
# will rename /media/m/1083-4BEC/rob de nijs - banger hart.mp3 to /media/m/1083-4BEC/1rob de nijs - banger hart.mp3
# will rename /media/m/1083-4BEC/Oh! Carol  -  The Blue Diamonds.mp3 to /media/m/1083-4BEC/2Oh! Carol  -  The Blue Diamonds.mp3
# will rename /media/m/1083-4BEC/Cartoon - On & On (Lyrics) feat. Daniel Levi.mp3 to /media/m/1083-4BEC/3Cartoon - On & On (Lyrics) feat. Daniel Levi.mp3
# will rename /media/m/1083-4BEC/Stef Bos - Papa lyrics.mp3 to /media/m/1083-4BEC/4Stef Bos - Papa lyrics.mp3
# will rename /media/m/1083-4BEC/C.Jérome - C'est moi.mp3 to /media/m/1083-4BEC/5C.Jérome - C'est moi.mp3
# will rename /media/m/1083-4BEC/John Lennon - Imagine (Lyrics)🎶.mp3 to /media/m/1083-4BEC/6John Lennon - Imagine (Lyrics)🎶.mp3
# ...

# %%
for count, file in enumerate(mp3s):
    print(file + '\n' + file)
# Out:
# Sukiyaki (Remastered)-T_WuE_AV6kg.mp3
# Sukiyaki (Remastered)-T_WuE_AV6kg.mp3
# rob de nijs - banger hart.mp3
# rob de nijs - banger hart.mp3
# Oh! Carol  -  The Blue Diamonds.mp3
# Oh! Carol  -  The Blue Diamonds.mp3
# Cartoon - On & On (Lyrics) feat. Daniel Levi.mp3
# Cartoon - On & On (Lyrics) feat. Daniel Levi.mp3
# Stef Bos - Papa lyrics.mp3
# Stef Bos - Papa lyrics.mp3
# C.Jérome - C'est moi.mp3
# C.Jérome - C'est moi.mp3
# John Lennon - Imagine (Lyrics)🎶.mp3
# John Lennon - Imagine (Lyrics)🎶.mp3
# Benny Neyman - Ga niet weg van mij  _ 1987 .mp3
# Benny Neyman - Ga niet weg van mij  _ 1987 .mp3
# The Ronettes - Be My Baby (Official Audio).mp3
# The Ronettes - Be My Baby (Official Audio).mp3
# The Beach Boys - Surfin' USA.mp3
# The Beach Boys - Surfin' USA.mp3
# ABBA Take a Chance On Me.mp3
# ABBA Take a Chance On Me.mp3
# China In Your Heart.mp3
# China In Your Heart.mp3
# Spanish Harlem.mp3
# Spanish Harlem.mp3
# Each Time You Break My Heart.mp3
# ...
